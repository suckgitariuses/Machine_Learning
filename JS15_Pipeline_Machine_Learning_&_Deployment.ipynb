# %% [markdown]
# <a href="https://colab.research.google.com/github/suckgitariuses/Machine_Learning/blob/main/JS15_Pipeline_Machine_Learning_%26_Deployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Adinda Mirza Devani**
#
# **TI-3B/04**
#
# **2341820046**

# %% [markdown]
# **JS15-PIPELINE MACHINE LEARINNG & DEPLOYMENT**

# %% [markdown]
# **Praktikum 1**
#
# Klasifikasi Gambar (Day vs Night) dengan Neural Network.

# %% [markdown]
# **Langkah 1: Import Library dan Mount Google Drive**

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import cv2

from skimage.feature import hog
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Langkah 2: Load Dataset**

# %%
# Load images and labels from a directory structure
def load_dataset(img_dir):
    p = Path(img_dir)
    img_list = []
    for folder in p.glob('*'):
        label = folder.name
        for file in folder.glob('*.jpg'):
            img = cv2.imread(str(file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img_list.append((img, label))
    return img_list

train_dir = "/content/drive/MyDrive/ML_dataset/images/training/"
test_dir  = "/content/drive/MyDrive/ML_dataset/images/test"

train_img = load_dataset(train_dir)
test_img  = load_dataset(test_dir)

print(f"Jumlah data training: {len(train_img)}")
print(f"Jumlah data testing: {len(test_img)}")
# Out:
# Jumlah data training: 240
# Jumlah data testing: 160

# %% [markdown]
# **Langkah 3: Preprocessing (Resize & Label Encoding)**
#
# Mengubah ukuran gambar menjadi 256x256 piksel dan mengubah label teks ('day'/'night') menjadi angka biner (1/0)

# %%
# Preprocess images: resize and encode labels
def resize_image(img, size=(256,256)):
    return cv2.resize(img, size)

def label_encoder(label):
    return 1 if label == 'day' else 0

def preprocess(img_list):
    X = []
    y = []
    for img, label in img_list:
        img_std = resize_image(img)
        X.append(img_std)
        y.append(label_encoder(label))
    return X, y

X_train_img, y_train = preprocess(train_img)
X_test_img,  y_test  = preprocess(test_img)

# %% [markdown]
# **Langkah 4: Ekstraksi Fitur HOG**

# %%
# Extract HOG features
def extract_hog(X_imgs):
    feats = []
    for img in X_imgs:
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        hog_feat = hog(gray,
                       orientations=9,
                       pixels_per_cell=(8,8),
                       cells_per_block=(2,2),
                       block_norm='L2-Hys',
                       visualize=False,
                       feature_vector=True)
        feats.append(hog_feat)
    return np.array(feats)

X_train_feat = extract_hog(X_train_img)
X_test_feat  = extract_hog(X_test_img)

# %% [markdown]
# **Langkah 5: Normalisasi Fitur**
#
# Menstandarisasi fitur agar memiliki rata-rata 0 dan variansi 1 menggunakan StandardScaler.

# %%
# Normalize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_feat)
X_test_scaled  = scaler.transform(X_test_feat)

# %% [markdown]
# **Langkah 6: Split Data Training & Validation**

# %%
# Split training data for validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train_scaled, y_train,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# **Langkah 7: Konversi Label ke Numpy Array**
#
# Mengubah list label menjadi format numpy array agar kompatibel dengan TensorFlow/Keras.

# %%
# Convert labels to numpy arrays (required for Keras)
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# %% [markdown]
# **Langkah 8: Membangun Arsitektur Model Neural Network**
#
# Membuat model Sequential dengan 3 layer (Input, Hidden Layers dengan ReLU, dan Output Layer dengan Sigmoid).

# %%
# Build a simple feedforward neural network
# Define model architecture
# input_dim is the number of features in the dataset
# Hidden layer -> 128 neurons, ReLU activation
# Hidden layer -> 64 neurons, ReLU activation
# Output layer -> 1 neuron, Sigmoid activation (for binary classification)
input_dim = X_train.shape[1]

model = models.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │     4,428,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,436,737 (16.92 MB)
#  Trainable params: 4,436,737 (16.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Langkah 9: Training Model**

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 317ms/step - accuracy: 0.6767 - loss: 1.4005 - val_accuracy: 0.9375 - val_loss: 0.1775
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - accuracy: 0.9928 - loss: 0.0263 - val_accuracy: 0.9583 - val_loss: 0.0780
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 0.9928 - loss: 0.0076 - val_accuracy: 0.9583 - val_loss: 0.5144
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 1.0000 - loss: 2.5515e-04 - val_accuracy: 0.9583 - val_loss: 0.7736
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 194ms/step - accuracy: 1.0000 - loss: 2.1280e-06 - val_accuracy: 0.9583 - val_loss: 0.9113
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 194ms/step - accuracy: 1.0000 - loss: 2.1517e-06 - val_accuracy: 0.9583 - val_loss: 0.9863
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 270ms/step - accuracy: 1.0000 - loss: 9.6620e-07 - val_accuracy: 0.9583 - val_loss: 1.0293
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - accuracy: 1.0000 - loss: 2.1863e-06 - val_accuracy: 0.9583 - val_loss: 1.0539
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 1.0000 - loss: 2.9878e-07 - val_accuracy: 0.9583 - val_loss: 1.0678
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 1.0000 - loss: 8.4276e-07 - val_accuracy: 0.9583 - val_loss: 1.0756
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 1.0000 - loss: 4.9494e-07 - val_accuracy: 0.9583 - val_loss: 1.0800
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 5.2674e-07 - val_accuracy: 0.9583 - val_loss: 1.0824
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 1.0000 - loss: 4.5942e-07 - val_accuracy: 0.9583 - val_loss: 1.0837
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 3.4237e-07 - val_accuracy: 0.9583 - val_loss: 1.0844
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 5.2405e-07 - val_accuracy: 0.9583 - val_loss: 1.0848
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 7.0803e-07 - val_accuracy: 0.9583 - val_loss: 1.0850
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 1.2579e-07 - val_accuracy: 0.9583 - val_loss: 1.0850
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 3.2439e-07 - val_accuracy: 0.9583 - val_loss: 1.0851
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 4.4169e-07 - val_accuracy: 0.9583 - val_loss: 1.0851
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 5.9317e-07 - val_accuracy: 0.9583 - val_loss: 1.0851

# %% [markdown]
# **Langkah 10: Evaluasi Model**

# %%
# Evaluate the model on test data
test_loss, test_acc = model.evaluate(X_test_scaled, y_test)
print("Akurasi Test:", test_acc)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8795 - loss: 2.3924
# Akurasi Test: 0.893750011920929

# %% [markdown]
# **Langkah 11: Prediksi dan Laporan Klasifikasi serta Visualisasi**
#
# Membuat prediksi pada data test dan menampilkan classification report serta confusion matrix.

# %%
# Generate classification report and confusion matrix
y_pred_prob = model.predict(X_test_scaled)
y_pred = (y_pred_prob > 0.5).astype(int)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89        80
#            1       0.86      0.94      0.90        80
#
#     accuracy                           0.89       160
#    macro avg       0.90      0.89      0.89       160
# weighted avg       0.90      0.89      0.89       160
#
# [[68 12]
#  [ 5 75]]

# %%
# Visualize training history
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# **Langkah 12: Menyimpan Model dan Scaler**
#
# Menyimpan model yang sudah dilatih ke dalam format .h5 dan scaler ke format .pkl untuk penggunaan deployment.

# %%
# Save the trained model
import pickle

# 1. Simpan Model
# Menggunakan format .h5
model.save('day_night_model.h5')
print("✅ Model berhasil disimpan sebagai: day_night_model.h5")

# 2. Simpan Scaler
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
print("✅ Scaler berhasil disimpan sebagai: scaler.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model berhasil disimpan sebagai: day_night_model.h5
# ✅ Scaler berhasil disimpan sebagai: scaler.pkl

# %% [markdown]
# **Praktikum 2**
#
# Deployment ke Hugging Face (Docker + Flask)

# %% [markdown]
# **Langkah 1: Persiapan Environment**

# %% [markdown]
# **1. Buat folder project**

# %%
import os

project_path = "/content/drive/MyDrive/ML_dataset/daynight-project"
os.makedirs(project_path, exist_ok=True)

project_path
# Out:
# '/content/drive/MyDrive/ML_dataset/daynight-project'

# %% [markdown]
# **2. Upload file model ke folder tersebut**

# %%
# Simpan model
model.save("day_night_model.h5")

# Simpan scaler
import joblib
joblib.dump(scaler, "scaler.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['scaler.pkl']

# %% [markdown]
# **3. Download file model dari colab ke komputer**
