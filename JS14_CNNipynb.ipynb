# %% [markdown]
# <a href="https://colab.research.google.com/github/suckgitariuses/Machine_Learning/blob/main/JS14_CNNipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Adinda Mirza Devani**
#
# **TI-3B/04**
#
# **2341720046**

# %% [markdown]
# **JS14 - CONCOLUTIONAL NEURAL NETWORK**

# %% [markdown]
# **Praktikum 1**
#
# Klasifikasi Cat vs Dog

# %% [markdown]
# **Langkah 1 - Import Library**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# **Langkah 2 - Pra Pengolahan Data**
#
# di tahap ini sedikit melakukan manipulasi pada citra yang digunakan. manipulasi normalisasi nilai piksel, koreksi kemiringan, zoom dan flip.

# %% [markdown]
# **Langkah 2.1. Pra Pengolahan Data Training**

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# **Langkah 2.2. Pra Pengolahan Data Testing**

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# **Langkah 3 - Pembuatan Model CNN**

# %% [markdown]
# **Langkah 3.1. - Inisiasi Model CNN**

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# **Langkah 3.2. - Pembuatan Layer Konvolusi 1**

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# **Langkah 3.3. - Pembuatan Layer Pooling 1**

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# **Langkah 3.4. - Pembuatan Layer Konvolusi 2 dan Pooling 2**

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# **Langkah 3.5 - Flattening**

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# **Langkah 3.6 - Fully Connected Layer 1 (Input)**

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# **Langkah 3.7 - Fully Connected Layer 2 (Output)**

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# **Langkah 3.8 - Compile Model CNN**

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# penggunaan ***loss function binary crossentropy*** dikarenakan kita hanya melakukan klasifikasi pada 2 kelas, yaitu kucing dan anjing.

# %% [markdown]
# **Langkah 4 - Fit CNN**

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 286s 1s/step - accuracy: 0.6644 - loss: 0.6095 - val_accuracy: 0.6925 - val_loss: 0.5734
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 95s 382ms/step - accuracy: 0.7137 - loss: 0.5587 - val_accuracy: 0.6760 - val_loss: 0.5997
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 92s 368ms/step - accuracy: 0.7279 - loss: 0.5399 - val_accuracy: 0.7155 - val_loss: 0.5511
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 95s 380ms/step - accuracy: 0.7576 - loss: 0.5036 - val_accuracy: 0.7535 - val_loss: 0.5242
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 140s 373ms/step - accuracy: 0.7578 - loss: 0.5031 - val_accuracy: 0.7600 - val_loss: 0.5084
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 95s 378ms/step - accuracy: 0.7711 - loss: 0.4785 - val_accuracy: 0.7885 - val_loss: 0.4707
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 94s 374ms/step - accuracy: 0.7736 - loss: 0.4606 - val_accuracy: 0.7590 - val_loss: 0.4979
# Epoch 8/25
# ...

# %% [markdown]
# **Langkah 5 - Prediksi dengan 1 Citra**

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
